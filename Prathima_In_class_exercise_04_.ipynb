# %% [markdown]
# <a href="https://colab.research.google.com/github/pn0159/prathima_INFO5731_Fall2020/blob/master/Prathima_In_class_exercise_04_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The fourth in-class-exercise (20 points in total)**

# %% [markdown]
# # 1. Text Data Preprocessing
#
# Here is a [legal case](https://github.com/unt-iialab/INFO5731_FALL2020/blob/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# ## 1.1 Basic feature extraction using text data (4 points)
#
# *   Number of sentences
# *   Number of words
# *   Number of characters
# *   Average word length
# *   Number of stopwords
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase words
#
# ## 1.2 Basic Text Pre-processing of text data (4 points)
#
# *   Lower casing
# *   Punctuation removal
# *   Stopwords removal
# *   Frequent words removal
# *   Rare words removal
# *   Spelling correction
# *   Tokenization
# *   Stemming
# *   Lemmatization
#
# ## 1.3 Save all the **clean sentences** to a **csv file** (one column, each raw is a sentence) after finishing all the steps above. (4 points)
#
#
# ## 1.4 Advance Text Processing (Extra credit: 4 points)
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 3-grams terms as features.

# %%
# Question1.1:

import requests
r=requests.get("https://raw.githubusercontent.com/unt-iialab/INFO5731_FALL2020/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt")
text=r.text

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
tokenized_sentences=(nltk.sent_tokenize(raw))
len(tokenized_sentences)
# Out:
# 173

# %%
import re
word1=[]
for each_sentence in tokenized_sentences:
  words=re.split(r'\W+', each_sentence)
  for i in words:
    word1.append(i)

# %%
len(word1)
# Out:
# 3899

# %%
sum=0
for i in word1:
  sum+=len(i)
sum
# Out:
# 15903

# %%
sum/len(word1)
# Out:
# 4.078738137984098

# %%
from nltk.corpus import stopwords
filtered_words = [word for word in word1 if word not in stopwords.words('english')]
len(word1)-len(filtered_words)
# Out:
# 1726

# %%
# Calculating the number of special characters:
# calculating the number of hashtags or mentions present in it. 
#This helps to extract extra information from our text data.
import collections as ct
words2=text.split()
number_words=len(words2)
special_chars = "#","$","&","%"
new=[v for k, v in ct.Counter(words2).items() if k in special_chars]
print("Total Special Characters", new)
# Out:
# Total Special Characters [5]

# %%
#Calculating the number of numerics:
# calculating the number of numeric data present in the text files.
# It is same as the calculation the number of characters in a word.
words4=(map(str.isdigit, re.split(r'\W+',text)))
sum=0 
for i in words4:
  sum+=i
print("TOTAL NUMERIC IN A TEXT FILE =",sum)
# Out:
# TOTAL NUMERIC IN A TEXT FILE = 155

# %%
#calculating number pf upper case letters:
#Using 'isupper()' function, we can calculate number of upper case letters in the text.
words5=(map(str.isupper, re.split(r'\W+',text))) 
sum=0 
for i in words5:
  sum+=i
print("TOTAL UPPERCASE WORDS IN A TEXT FILE =",sum)
# Out:
# TOTAL UPPERCASE WORDS IN A TEXT FILE = 92

# %%
1.2
# Out:
# 1.2

# %%
# Question 1.2:Text pre-processing of text data
#Lower casing:
#Lower casing is a common text preprocessing technique. 
#The idea is to convert the input text into same casing format so that 'text', 'Text' and 'TEXT' are treated the same way
lower_word=[]
for i in word1:
  lower_word.append(i.lower())

# %%
#Rare words removal
#This is very similar to previous preprocessing step but we will remove the rare words from the corpus.
from nltk.probability import FreqDist
freq_dist=nltk.FreqDist(word1)
rarewords = list(freq_dist.keys())[-5:]
after_rare_words = [ word for word in word1 if word not in rarewords]

# %%
#stemming
#Stemming is the process of reducing inflected (or sometimes derived) words to their word stem, base or root form

from nltk.stem import PorterStemmer 
ps = PorterStemmer() 
for w in word1: 
    print(w, " : ", ps.stem(w))
# Out:
#   :
# 5  :  5
# Ala  :  ala
# 740  :  740
# Supreme  :  suprem
# Court  :  court
# of  :  of
# Alabama  :  alabama
#   :
# ADAMS  :  adam
# v  :  v
# TANNER  :  tanner
# AND  :  and
# HORTON  :  horton
#   :
# June  :  june
# Term  :  term
# 1843  :  1843
#   :
# Synopsis  :  synopsi
# WRIT  :  writ
# of  :  of
# Error  :  error
# to  :  to
# the  :  the
# Circuit  :  circuit
# Court  :  court
# of  :  of
# Sumter  :  sumter
#   :
# West  :  west
# Headnotes  :  headnot
# 2  :  2
# 1  :  1
# Chattel  :  chattel
# Mortgages  :  mortgag
# Crops  :  crop
# A  :  A
# growing  :  grow
# crop  :  crop
# has  :  ha
# such  :  such
# an  :  an
# existence  :  exist
# as  :  as
# to  :  to
# be  :  be
# the  :  the
# subject  :  subject
# matter  :  matter
# of  :  of
# a  :  a
# mortgage  :  mortgag
# or  :  or
# other  :  other
# contract  :  contract
# which  :  which
# passes  :  pass
# an  :  an
# interest  :  interest
# to  :  to
# vest  :  vest
# in  :  in
# possession  :  possess
# ...

# %%
#lemetization
#Lemmatization is similar to stemming in reducing inflected words to their word stem but differs in the way that it makes sure the root  belongs to the language.
from nltk.stem import WordNetLemmatizer 
  
lemmatizer = WordNetLemmatizer() 
for i in word1:
  print(lemmatizer.lemmatize(i))
# Out:
# 5
# Ala
# 740
# Supreme
# Court
# of
# Alabama
#
# ADAMS
# v
# TANNER
# AND
# HORTON
#
# June
# Term
# 1843
#
# Synopsis
# WRIT
# of
# Error
# to
# the
# Circuit
# Court
# of
# Sumter
#
# West
# Headnotes
# 2
# 1
# Chattel
# Mortgages
# Crops
# A
# growing
# crop
# ha
# such
# an
# existence
# a
# to
# be
# the
# subject
# matter
# of
# a
# mortgage
# or
# other
# contract
# which
# pass
# an
# interest
# to
# vest
# in
# possession
# either
# immediately
# or
# at
# a
# future
# time
#
# 4
# Cases
# that
# cite
# this
# headnote
# 2
# Creditors
# Remedies
# Lien
# and
# Priority
# Under
# St
# 1821
# prohibiting
# a
# levy
# on
# a
# crop
# until
# it
# ha
# been
# gathered
# no
# lien
# attache
# in
# favor
# of
# a
# fi
#
# fa
#
# on
# a
# growing
# crop
# nor
# doe
# such
# lien
# attach
# until
# after
# the
# crop
# ha
# been
# gathered
#
# 5
# Cases
# that
# cite
# this
# headnote
# 1
# This
# wa
# a
# trial
# of
# the
# right
# of
# property
# under
# the
# statute
#
# In
# ...

# %%
pip install autocorrect

# %%
#selling correction
#One another important text preprocessing step is spelling correction.
# Typos are common in text data and we might want to correct those spelling mistakes before we do our analysis.
from autocorrect import Speller

spell = Speller(lang='en')
final1=[]
for i in word1:
  final1.append(spell(i))

# %%
import pandas as pd
df=pd.DataFrame(final)
df.to_csv('filename.csv', index=False)

# %% [markdown]
# # 2. Python Regular Expression

# %% [markdown]
# ## 2.1 Write a Python program to remove leading zeros from an IP address. (4 points)
#
# ip = "260.08.094.109"

# %%
# I am gonna use 're' module which is used for regular expressions
import re
given_ip="260.08.094.109"

#I am using 're.sub' function of 're' module to replace substrings
#re.sub(pattern,repl,string).so i am replacing '.[0]' with '.'
rem_lead_zeros=re.sub('\.[0]*' ,'.', given_ip)

#Finally printing the output after removing leading zeros
print("The IP Address after removing leading zeros is:\n", rem_lead_zeros)
# Out:
# The IP Address after removing leading zeros is:
#  260.8.94.109

# %% [markdown]
# ## 2.2 Write a Python Program to extract all the years from the following sentence. (4 points)
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# %%
## I am gonna use 're' module which is used for regular expressions
import re
import datetime
from datetime import date
my_sentence="The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

#I am using 'findall()'module is used to search for all occurrences that match a given pattern
my_find=re.findall(r'([2]\d{3})' , my_sentence)
print(my_find)

#Removing duplicates
mylist = list(dict.fromkeys(my_find))
print("The years extracted from the given sentence are:\n" , mylist)
# Out:
# ['2010', '2010', '2019']
# The years extracted from the given sentence are:
#  ['2010', '2019']
